23       V24       V25       V26       V27       V28  Amount
# ...

# %%
Y_train.head()
# Out:
# 100623    1
# 145372    0
# 66136     0
# 110587    0
# 54854     0
# Name: Class, dtype: int64

# %%
X_test.head()
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 247995  153761.0   1.146259   1.403458  -4.159148  2.660107  -0.323217
# 233712  147674.0   0.072713   0.831611   0.408578 -0.606621   0.636705
# 158659  111607.0  -0.902748   0.887172   0.398361  0.714372   0.961021
# 117386   74658.0   1.212794   0.324899   0.632411  0.754231  -0.589028
# 15451    26833.0 -20.532751  12.373989 -23.009003  6.144821 -15.587296
#
#               V6         V7         V8        V9  ...       V20       V21  \
# 247995 -1.836071  -1.623740   0.259562 -1.132044  ...  0.284831  0.564450
# 233712 -1.000297   1.074354  -0.292808 -0.336575  ... -0.103755 -0.212097
# 158659  2.591877  -0.567820   0.418241 -0.061789  ... -0.432517  0.462237
# 117386 -1.311763   0.225555  -0.329543 -0.184176  ... -0.029835 -0.150310
# 15451  -4.384491 -15.939003  13.696416 -3.948455  ...  1.592754  1.754608
#
#              V22       V23       V24       V25       V26       V27       V28  \
# ...

# %%
Y_test.head()
# Out:
# 247995    1
# 233712    0
# 158659    0
# 117386    0
# 15451     1
# Name: Class, dtype: int64

# %%
Y_train.value_counts()
# Out:
# Class
# 1    394
# 0    393
# Name: count, dtype: int64

# %%
Y_test.value_counts()
# Out:
# Class
# 0    99
# 1    98
# Name: count, dtype: int64

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_predict=lr.predict(X_test)

# %%
accuracy_score(Y_test,Y_predict)
# Out:
# 0.9137055837563451

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_predict2=rf.predict(X_test)

# %%
accuracy_score(Y_predict2,Y_test)
# Out:
# 0.9187817258883249

# %%
sq=Sequential()

# %%
sq.add(Dense(30,activation='relu'))

# %%
sq.add(Dense(20,activation='relu'))

# %%
sq.add(Dense(30,activation='relu'))

# %%
sq.add(Dense(1,activation='sigmoid'))

# %%
sq.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
sq.fit(X_train,Y_train,validation_split=0.33,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 0s 2ms/step - loss: 1758.1696 - accuracy: 0.4801 - val_loss: 17.4965 - val_accuracy: 0.4769
# Epoch 2/100
# 53/53 [==============================] - 0s 841us/step - loss: 38.0013 - accuracy: 0.5237 - val_loss: 15.9342 - val_accuracy: 0.5615
# Epoch 3/100
# 53/53 [==============================] - 0s 806us/step - loss: 36.3465 - accuracy: 0.5370 - val_loss: 29.6467 - val_accuracy: 0.5462
# Epoch 4/100
# 53/53 [==============================] - 0s 810us/step - loss: 32.0770 - accuracy: 0.5446 - val_loss: 17.4742 - val_accuracy: 0.4731
# Epoch 5/100
# 53/53 [==============================] - 0s 792us/step - loss: 24.1616 - accuracy: 0.5579 - val_loss: 36.8655 - val_accuracy: 0.5500
# Epoch 6/100
# 53/53 [==============================] - 0s 808us/step - loss: 34.3167 - accuracy: 0.5617 - val_loss: 50.7926 - val_accuracy: 0.4731
# Epoch 7/100
# ...
